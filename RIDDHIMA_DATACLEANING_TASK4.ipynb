# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp

# %% [markdown]
# IMPORTING CSV FILE AS DATAFRAME

# %%
data=pd.read_csv("Task_4.csv")

# %%
data
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad  guestroom  \
# 0    13300000  7420.0       4.0        NaN      3.0      NaN        NaN
# 1    12250000  8960.0       NaN        4.0      4.0      yes         no
# 2    12250000  9960.0       3.0        2.0      2.0      yes        NaN
# 3    12215000  7500.0       NaN        NaN      NaN      NaN         no
# 4    11410000  7420.0       NaN        1.0      2.0      NaN  Of course
# ..        ...     ...       ...        ...      ...      ...        ...
# 540   1820000     NaN       2.0        NaN      1.0      NaN         no
# 541   1767150     NaN       3.0        1.0      1.0       no       ille
# 542   1750000  3620.0       NaN        NaN      NaN      yes         no
# 543   1750000     NaN       NaN        1.0      1.0       no         no
# 544   1750000  3850.0       3.0        1.0      2.0      NaN        NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
corr_matrix=data.corr()
corr_matrix
# Out:
# C:\Users\Riddhima\AppData\Local\Temp\ipykernel_6588\829720740.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=data.corr()
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.541466  0.381045   0.537626  0.471750  0.373763
# area       0.541466  1.000000  0.196995   0.312273  0.124203  0.377910
# bedrooms   0.381045  0.196995  1.000000   0.457968  0.425873  0.120843
# bathrooms  0.537626  0.312273  0.457968   1.000000  0.349923  0.148495
# stories    0.471750  0.124203  0.425873   0.349923  1.000000  0.083874
# parking    0.373763  0.377910  0.120843   0.148495  0.083874  1.000000

# %% [markdown]
# DROPPING DUPLICATE ROWS (IF ANY)

# %%
data=data.drop_duplicates()
data
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad  guestroom  \
# 0    13300000  7420.0       4.0        NaN      3.0      NaN        NaN
# 1    12250000  8960.0       NaN        4.0      4.0      yes         no
# 2    12250000  9960.0       3.0        2.0      2.0      yes        NaN
# 3    12215000  7500.0       NaN        NaN      NaN      NaN         no
# 4    11410000  7420.0       NaN        1.0      2.0      NaN  Of course
# ..        ...     ...       ...        ...      ...      ...        ...
# 540   1820000     NaN       2.0        NaN      1.0      NaN         no
# 541   1767150     NaN       3.0        1.0      1.0       no       ille
# 542   1750000  3620.0       NaN        NaN      NaN      yes         no
# 543   1750000     NaN       NaN        1.0      1.0       no         no
# 544   1750000  3850.0       3.0        1.0      2.0      NaN        NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# PRINTS TOTAL NAN VALUES IN THE DATASET

# %%
data.isnull().sum()
# data.isnull().sum().sum()
# Out:
# price                 0
# area                206
# bedrooms            187
# bathrooms           183
# stories             185
# mainroad            194
# guestroom           210
# basement            204
# hotwaterheating     204
# airconditioning     188
# parking             208
# prefarea            188
# furnishingstatus    187
# dtype: int64

# %% [markdown]
# PRINTS UNIQUE VALUES OF COLUMNS BASEMENT,MAINROAD,GUESTROOM

# %%
print(data.basement.unique())
print(data.mainroad.unique())
print(data.guestroom.unique())
print(data.prefarea.unique())
# Out:
# [nan 'no' 'yes' 'Haanji' 'N' 'Naaji' 'n' 'y' 'False' 'Haan' 'Nakko' 'ille'
#  'Nah' 'True' 'yep' 'Nope' 'Indeed' "['n']" 'Of course' 'Y' 'Yo']
# [nan 'yes' 'Of course' 'Indeed' 'yep' 'Haan' 'True' 'y' 'Y' "['y']" 'Nope'
#  'Yo' 'no' 'Haanji' 'Nakko' 'False' 'Naaji' 'N' 'n']
# [nan 'no' 'Of course' 'yes' 'ille' 'y' 'N' 'Yo' 'Nakko' 'Y' 'Naaji' 'n'
#  'False' "['n']" 'Haan' 'Nah' 'yep' 'Haanji' 'True' 'Nope' 'Indeed']
# ['Haanji' 'no' 'yes' 'Haan' nan 'Of course' 'Nakko' 'Nope' 'ille' 'N'
#  'yep' 'y' 'Naaji' 'True' 'Y' 'n' "['n']" 'False' 'Yo' 'Nah']

# %% [markdown]
# PUTTING ALL UNIQUES OF YES/NO IN A LIST TO REPLACE THEM

# %%
stringsy=['Haanji','True','Indeed','y','Yo','yep','yes','Haan','Of course','Y',"['y']"]
repy='YES'
stringsn=['no','Nakko','False','Nah','n','N','Naaji','Nope','ille',"['n']"]
repn='NO'

# %% [markdown]
# REPLACING ALL Y,YEP,HAANJI etc with YES AND n.NAHH,NAAJI etc with NO

# %%
#putting yes
data['basement']=data['basement'].replace(stringsy,repy)
data["mainroad"]=data["mainroad"].replace(stringsy,repy)
data["guestroom"]=data["guestroom"].replace(stringsy,repy)
data["hotwaterheating"]=data["hotwaterheating"].replace(stringsy,repy)
data["prefarea"]=data["prefarea"].replace(stringsy,repy)
data["airconditioning"]=data["airconditioning"].replace(stringsy,repy)
#putting no
data['basement']=data['basement'].replace(stringsn,repn)
data["mainroad"]=data["mainroad"].replace(stringsn,repn)
data["guestroom"]=data["guestroom"].replace(stringsn,repn)
data["hotwaterheating"]=data["hotwaterheating"].replace(stringsn,repn)
data["prefarea"]=data["prefarea"].replace(stringsn,repn)
data["airconditioning"]=data["airconditioning"].replace(stringsn,repn)
data
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        NaN      3.0      NaN       NaN
# 1    12250000  8960.0       NaN        4.0      4.0      YES        NO
# 2    12250000  9960.0       3.0        2.0      2.0      YES       NaN
# 3    12215000  7500.0       NaN        NaN      NaN      NaN        NO
# 4    11410000  7420.0       NaN        1.0      2.0      NaN       YES
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000     NaN       2.0        NaN      1.0      NaN        NO
# 541   1767150     NaN       3.0        1.0      1.0       NO        NO
# 542   1750000  3620.0       NaN        NaN      NaN      YES        NO
# 543   1750000     NaN       NaN        1.0      1.0       NO        NO
# 544   1750000  3850.0       3.0        1.0      2.0      NaN       NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# REMOVING COLUMNS HAVING THRESHOLD OF 8 NAN VALUES

# %%
data=data.dropna(axis=0,thresh=9)
data = data.reset_index(drop=True)
data.shape
# Out:
# (306, 13)

# %% [markdown]
# USING INTERPOLATE TO FILL NAN VALUES IN THE COLUMN AREA

# %%
data['area']=data['area'].interpolate(method='linear').fillna(1).astype(int)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960       NaN        4.0      4.0      YES        NO
# 1    12250000   9960       3.0        2.0      2.0      YES       NaN
# 2    12215000   7500       NaN        NaN      NaN      NaN        NO
# 3    11410000   7420       NaN        1.0      2.0      NaN       YES
# 4    10150000  16200       5.0        3.0      2.0      NaN       NaN
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000       4.0        NaN      2.0      NaN        NO
# 302   1960000   3324       NaN        1.0      2.0       NO       NaN
# 303   1890000   3649       2.0        1.0      NaN      NaN        NO
# 304   1767150   3649       3.0        1.0      1.0       NO        NO
# 305   1750000   3649       NaN        1.0      1.0       NO        NO
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# DISPLAY.MAX_ROWS HELPS DISPLAY ALL ROWS INSTEAD OF FIRST 5 AND LAST 5

# %%
# pd.set_option('display.max_rows', None)
# data

# %% [markdown]
# PUTTING no in place of nan values in a column having unfurnished as furnishing status

# %%
data = data.apply(lambda row: row.fillna('NO') if 'unfurnished' in row.values else row, axis=1)
data
# Out:
#         price   area bedrooms bathrooms stories mainroad guestroom basement  \
# 0    12250000   8960      NaN       4.0     4.0      YES        NO       NO
# 1    12250000   9960      3.0       2.0     2.0      YES       NaN      YES
# 2    12215000   7500      NaN       NaN     NaN      NaN        NO      YES
# 3    11410000   7420      NaN       1.0     2.0      NaN       YES      YES
# 4    10150000  16200      5.0       3.0     2.0      NaN       NaN       NO
# ..        ...    ...      ...       ...     ...      ...       ...      ...
# 301   2100000   3000      4.0        NO     2.0       NO        NO       NO
# 302   1960000   3324       NO       1.0     2.0       NO        NO       NO
# 303   1890000   3649      2.0       1.0     NaN      NaN        NO       NO
# 304   1767150   3649      3.0       1.0     1.0       NO        NO       NO
# 305   1750000   3649      NaN       1.0     1.0       NO        NO       NO
#
# ...

# %%
data['bedrooms']=data['bedrooms'].replace('NO',np.nan)
data['bathrooms']=data['bathrooms'].replace('NO',np.nan)
data['stories']=data['stories'].replace('NO',np.nan)
data['parking']=data['parking'].replace('NO',np.nan)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960       NaN        4.0      4.0      YES        NO
# 1    12250000   9960       3.0        2.0      2.0      YES       NaN
# 2    12215000   7500       NaN        NaN      NaN      NaN        NO
# 3    11410000   7420       NaN        1.0      2.0      NaN       YES
# 4    10150000  16200       5.0        3.0      2.0      NaN       NaN
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000       4.0        NaN      2.0       NO        NO
# 302   1960000   3324       NaN        1.0      2.0       NO        NO
# 303   1890000   3649       2.0        1.0      NaN      NaN        NO
# 304   1767150   3649       3.0        1.0      1.0       NO        NO
# 305   1750000   3649       NaN        1.0      1.0       NO        NO
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['bedrooms'] = data['bedrooms'].interpolate(method='linear').fillna(2).astype(int)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES       NaN
# 2    12215000   7500         3        NaN      NaN      NaN        NO
# 3    11410000   7420         4        1.0      2.0      NaN       YES
# 4    10150000  16200         5        3.0      2.0      NaN       NaN
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        NaN      2.0       NO        NO
# 302   1960000   3324         3        1.0      2.0       NO        NO
# 303   1890000   3649         2        1.0      NaN      NaN        NO
# 304   1767150   3649         3        1.0      1.0       NO        NO
# 305   1750000   3649         3        1.0      1.0       NO        NO
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['bathrooms'].fillna(data['bedrooms'] - 1, inplace=True)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES       NaN
# 2    12215000   7500         3        2.0      NaN      NaN        NO
# 3    11410000   7420         4        1.0      2.0      NaN       YES
# 4    10150000  16200         5        3.0      2.0      NaN       NaN
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO        NO
# 302   1960000   3324         3        1.0      2.0       NO        NO
# 303   1890000   3649         2        1.0      NaN      NaN        NO
# 304   1767150   3649         3        1.0      1.0       NO        NO
# 305   1750000   3649         3        1.0      1.0       NO        NO
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
mean_value = int(data['stories'].mean())
data['stories'].fillna(mean_value, inplace=True)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES       NaN
# 2    12215000   7500         3        2.0      1.0      NaN        NO
# 3    11410000   7420         4        1.0      2.0      NaN       YES
# 4    10150000  16200         5        3.0      2.0      NaN       NaN
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO        NO
# 302   1960000   3324         3        1.0      2.0       NO        NO
# 303   1890000   3649         2        1.0      1.0      NaN        NO
# 304   1767150   3649         3        1.0      1.0       NO        NO
# 305   1750000   3649         3        1.0      1.0       NO        NO
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['mainroad'].fillna('YES',inplace=True)
data['hotwaterheating'].fillna('NO',inplace=True)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES       NaN
# 2    12215000   7500         3        2.0      1.0      YES        NO
# 3    11410000   7420         4        1.0      2.0      YES       YES
# 4    10150000  16200         5        3.0      2.0      YES       NaN
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO        NO
# 302   1960000   3324         3        1.0      2.0       NO        NO
# 303   1890000   3649         2        1.0      1.0      YES        NO
# 304   1767150   3649         3        1.0      1.0       NO        NO
# 305   1750000   3649         3        1.0      1.0       NO        NO
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
mp.scatter(data['parking'], data['price'],s=5)
mp.title('plotting parking vs. price')
mp.xlabel('parking')
mp.ylabel('price')
mp.show()
# mean = data['parking'].mean()
data['parking'].fillna(0, inplace=True)

# %%
data['airconditioning'].fillna(method='ffill',inplace=True)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES       NaN
# 2    12215000   7500         3        2.0      1.0      YES        NO
# 3    11410000   7420         4        1.0      2.0      YES       YES
# 4    10150000  16200         5        3.0      2.0      YES       NaN
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO        NO
# 302   1960000   3324         3        1.0      2.0       NO        NO
# 303   1890000   3649         2        1.0      1.0      YES        NO
# 304   1767150   3649         3        1.0      1.0       NO        NO
# 305   1750000   3649         3        1.0      1.0       NO        NO
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['guestroom'] = data['area'].apply(lambda x: 'YES' if 2000 <= x <= 7000 else 'NO')
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES        NO
# 2    12215000   7500         3        2.0      1.0      YES        NO
# 3    11410000   7420         4        1.0      2.0      YES        NO
# 4    10150000  16200         5        3.0      2.0      YES        NO
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO       YES
# 302   1960000   3324         3        1.0      2.0       NO       YES
# 303   1890000   3649         2        1.0      1.0      YES       YES
# 304   1767150   3649         3        1.0      1.0       NO       YES
# 305   1750000   3649         3        1.0      1.0       NO       YES
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
yes = data['furnishingstatus'].eq('YES').sum()
no= data['furnishingstatus'].eq('NO').sum()
if yes >3:
    data['furnishingstatus'].fillna('FURNISHED',inplace=True)
elif no>3:
    data['furnishingstatus'].fillna('UNFURNISHED',inplace=True)
else:
    data['furnishingstatus'].fillna('SEMI-FURNISHED',inplace=True)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES        NO
# 2    12215000   7500         3        2.0      1.0      YES        NO
# 3    11410000   7420         4        1.0      2.0      YES        NO
# 4    10150000  16200         5        3.0      2.0      YES        NO
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO       YES
# 302   1960000   3324         3        1.0      2.0       NO       YES
# 303   1890000   3649         2        1.0      1.0      YES       YES
# 304   1767150   3649         3        1.0      1.0       NO       YES
# 305   1750000   3649         3        1.0      1.0       NO       YES
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['furnishingstatus']=data['furnishingstatus'].replace('semi-furnished','SEMI-FURNISHED')
data['furnishingstatus']=data['furnishingstatus'].replace('furnished','FURNISHED')
data['furnishingstatus']=data['furnishingstatus'].replace('unfurnished','UNFURNISHED')
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES        NO
# 2    12215000   7500         3        2.0      1.0      YES        NO
# 3    11410000   7420         4        1.0      2.0      YES        NO
# 4    10150000  16200         5        3.0      2.0      YES        NO
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO       YES
# 302   1960000   3324         3        1.0      2.0       NO       YES
# 303   1890000   3649         2        1.0      1.0      YES       YES
# 304   1767150   3649         3        1.0      1.0       NO       YES
# 305   1750000   3649         3        1.0      1.0       NO       YES
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['basement'].replace({'YES':1,'NO':0},inplace=True)
m=data['basement'].mode()
m
# Out:
# 0    0.0
# Name: basement, dtype: float64

# %%
# mp.scatter(data['basement'], data['area'],s=5)
# mp.title('plotting Basement vs. Area')
# mp.xlabel('Basement')
# mp.ylabel('area')
# mp.show()

# %%
data['basement'].fillna(m,inplace=True)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES        NO
# 2    12215000   7500         3        2.0      1.0      YES        NO
# 3    11410000   7420         4        1.0      2.0      YES        NO
# 4    10150000  16200         5        3.0      2.0      YES        NO
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO       YES
# 302   1960000   3324         3        1.0      2.0       NO       YES
# 303   1890000   3649         2        1.0      1.0      YES       YES
# 304   1767150   3649         3        1.0      1.0       NO       YES
# 305   1750000   3649         3        1.0      1.0       NO       YES
#
#      basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['basement'].replace({1:'YES',0:'NO'},inplace=True)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES        NO
# 2    12215000   7500         3        2.0      1.0      YES        NO
# 3    11410000   7420         4        1.0      2.0      YES        NO
# 4    10150000  16200         5        3.0      2.0      YES        NO
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO       YES
# 302   1960000   3324         3        1.0      2.0       NO       YES
# 303   1890000   3649         2        1.0      1.0      YES       YES
# 304   1767150   3649         3        1.0      1.0       NO       YES
# 305   1750000   3649         3        1.0      1.0       NO       YES
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data['prefarea'].replace({'YES':1,'NO':0},inplace=True)
m1=data['prefarea'].mode()
m1
# Out:
# 0    0.0
# Name: prefarea, dtype: float64

# %%
# mp.scatter(data['basement'], data['area'],s=5)
# mp.title('plotting prefarea vs. Area')
# mp.xlabel('prefarea')
# mp.ylabel('area')
# mp.show()

# %%
data['prefarea'].fillna(m1,inplace=True)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES        NO
# 2    12215000   7500         3        2.0      1.0      YES        NO
# 3    11410000   7420         4        1.0      2.0      YES        NO
# 4    10150000  16200         5        3.0      2.0      YES        NO
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO       YES
# 302   1960000   3324         3        1.0      2.0       NO       YES
# 303   1890000   3649         2        1.0      1.0      YES       YES
# 304   1767150   3649         3        1.0      1.0       NO       YES
# 305   1750000   3649         3        1.0      1.0       NO       YES
#
#     basement hotwaterheating airconditioning  parking  prefarea  \
# ...

# %%
data['prefarea'].replace({1:'YES',0:'NO'},inplace=True)
data
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    12250000   8960         2        4.0      4.0      YES        NO
# 1    12250000   9960         3        2.0      2.0      YES        NO
# 2    12215000   7500         3        2.0      1.0      YES        NO
# 3    11410000   7420         4        1.0      2.0      YES        NO
# 4    10150000  16200         5        3.0      2.0      YES        NO
# ..        ...    ...       ...        ...      ...      ...       ...
# 301   2100000   3000         4        3.0      2.0       NO       YES
# 302   1960000   3324         3        1.0      2.0       NO       YES
# 303   1890000   3649         2        1.0      1.0      YES       YES
# 304   1767150   3649         3        1.0      1.0       NO       YES
# 305   1750000   3649         3        1.0      1.0       NO       YES
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data.to_csv('datacleaned.csv')
